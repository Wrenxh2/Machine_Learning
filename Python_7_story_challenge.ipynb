# %% [markdown]
# <a href="https://colab.research.google.com/github/Wrenxh2/Machine_Learning/blob/main/Python_7_story_challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 7_Story_Challenge
#
# In this notebook you will create a story that prints out to the user. You will ask the user questions that will be inserted into the story. You can use multiple print statements or one huge one, it's up to you!

# %% [markdown]
# ### Planning the Story
#
# Think of the different elements you want to have in your story. You'll need to create variables to address each of the following elements:
#
# *   Character Type (e.g., "Dragon")
# *   Character's Name (e.g., "Flare")
# *   Second Character's Name (e.g., "Geoff")
# *   Second Character's Occupation (e.g., "butcher")
# *   First Setting Place (e.g., "sea")
# *   Second Setting Place (e.g., "city")
# *   Plural Noun (e.g., "trees")
# *   Another Plural Noun (e.g., "bushes")
# *   Action (e.g., "fight")
# *   Adjective 1 (e.g., "happy")
# *   Another Adjective (e.g., "unpleasant")
# *   Past Tense Verb (e.g, "ate")
# *   Another Past Tense Verb (e.g., "sounded")
# *   Single Letter or Symbol (e.g., "a")
#
# You can also add more elements to your story!
#
# ![planning.png](data:image/png;base64,...)

# %% [markdown]
# ## Writing the Story
# Before writing the code, write a 6 to 8 line story on paper with the variables you created.
#
# For example, here are seven lines about a dragon:
#
# 1.   Once upon a time, there was a happy dragon named Flare.
# 2.   Flare was 1000 years old and lived by the sea.
# 3.   He ate trees and bushes.
# 4.   People thought Flare was too happy.
# 5.   So the people sent Geoff, the village's butcher, to fight the dragon.
# 6.   Flare thought that sounded unpleasant, so he left the sea.
# 7.   Now, he lives in the city and eats the trees and bushes there instead.
#
# ![dragon.jpeg](data:image/jpeg;base64,...)

# %%
# Declare variables for each of the Mad Lib elements.
import random
Andy_likes="Movies"
Andy_dislikes="Spiders"
dice_roll = random.randint(0,10)
print(dice_roll)

if dice_roll < 5:
  print("Andy moves on to see his favorite movie")

if dice_roll > 5:
  print("Andy moves on to find a cave full of spiders")
# Out:
# 7
# Andy moves on to find a cave full of spiders

# %%
# Create a variable called story and write your Mad Lib story by combining strings.
story = "Andy ended up in a dungeons and dragons game and unfortunately, he has to roll between 0 and 5 or 6 and 10 to either see his favorite movie or end up in a cave full of spiders. Andy ends up rolling a " + str(dice_roll) + " and ends up in a cave full of spiders"
print(story)
# Out:
# Andy ended up in a dungeons and dragons game and unfortunately, he has to roll between 0 and 5 or 6 and 10 to either see his favorite movie or end up in a cave full of spiders. Andy ends up rolling a 7 and ends up in a cave full of spiders

# %% [markdown]
# ###Extra Bonus Challenge
#
# Create a choose your own adventure story that gets user input to choose a path through the story. Use conditionals to print different stories depending on what the user wants to do. Have someone play your game and go through your story!
